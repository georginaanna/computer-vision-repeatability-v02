# %% [markdown]
# Script for obtaining access into git repository
#
# Aim this script will replace  the master script, "__master_trainer.ipynb" change the epochs to 100 and then visulise the results.
#
# Git
#
# save work via git commit -m "message"
# get the status via !git status
# push your work !git push

# %%
# mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# define github parameters
# personal access token valid until April
username = 'georginaanna'
repository = 'computer-vision-repeatability-v02'
git_token = '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'

# %%
# clone in the repository
# !git clone https://{git_token}@github.com/{username}/{repository}
# Out:
# Cloning into 'computer-vision-repeatability-v02'...
# remote: Enumerating objects: 1876, done.
# remote: Total 1876 (delta 0), reused 0 (delta 0), pack-reused 1876
# Receiving objects: 100% (1876/1876), 146.93 MiB | 29.40 MiB/s, done.
# Resolving deltas: 100% (603/603), done.
# Updating files: 100% (2543/2543), done.

# %%
# change the directory to the repository
# %cd /content/computer-vision-repeatability-v02
# Out:
# /content/computer-vision-repeatability-v02

# %%
# list what is in the repository
# %ls -a
# Out:
# ./        colab-notebooks/     Exp2-data-stems/  .gitignore              README.md
# ../       Exp0-repeatability/  .git/             __master_trainer.ipynb  stems-joe/
# coco128/  Exp1-data-dist/      .gitattributes    objectives.pptx         yaml-files/

# %%
# !git add 'Untitled0.ipynb'
# Out:
# fatal: pathspec 'Untitled0.ipynb' did not match any files
